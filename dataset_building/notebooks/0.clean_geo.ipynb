# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('../data/COVID-19_Case_Surveillance_Public_Use_Data_with_Geography.csv')
# Out:
# C:\Users\paulsaegert\AppData\Local\Programs\Python\Python39\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data
# Out:
#          case_month res_state  state_fips_code res_county  county_fips_code  \
# 0           2020-12        MN             27.0      DODGE           27039.0
# 1           2020-11        MI             26.0    GLADWIN           26051.0
# 2           2021-04        VT             50.0    ORLEANS           50019.0
# 3           2020-11        AL              1.0  LIMESTONE            1083.0
# 4           2021-01        NY             36.0  SCHOHARIE           36095.0
# ...             ...       ...              ...        ...               ...
# 27879428    2020-07        GA             13.0        NaN               NaN
# 27879429    2020-07        GA             13.0        NaN               NaN
# 27879430    2020-07        GA             13.0        NaN               NaN
# 27879431    2020-07        GA             13.0        NaN               NaN
# 27879432    2020-07        GA             13.0        NaN               NaN
#
#                age_group     sex     race ethnicity  \
# 0         18 to 49 years     NaN      NaN       NaN
# 1         18 to 49 years     NaN      NaN       NaN
# 2         18 to 49 years     NaN      NaN       NaN
# 3           0 - 17 years  Female  Missing   Missing
# 4           0 - 17 years  Female      NaN       NaN
# ...                  ...     ...      ...       ...
# 27879428    0 - 17 years    Male  Unknown   Missing
# 27879429    0 - 17 years    Male  Unknown   Missing
# 27879430    0 - 17 years    Male  Unknown   Missing
# 27879431    0 - 17 years    Male  Unknown   Missing
# 27879432    0 - 17 years    Male  Unknown   Missing
#
#           case_positive_specimen_interval  case_onset_interval   process  \
# 0                                    -1.0                  0.0   Missing
# 1                                     NaN                  NaN   Missing
# 2                                     0.0                  0.0  Multiple
# 3                                     NaN                  NaN   Missing
# 4                                     0.0                  NaN   Missing
# ...                                   ...                  ...       ...
# 27879428                              NaN                  NaN   Missing
# 27879429                              NaN                  NaN   Missing
# 27879430                              NaN                  NaN   Missing
# 27879431                              NaN                  NaN   Missing
# 27879432                              NaN                  NaN   Missing
#
#          exposure_yn             current_status symptom_status  hosp_yn  \
# 0            Missing  Laboratory-confirmed case    Symptomatic  Missing
# 1            Missing  Laboratory-confirmed case        Missing  Missing
# 2                Yes  Laboratory-confirmed case    Symptomatic       No
# 3            Missing  Laboratory-confirmed case        Missing  Missing
# 4            Missing  Laboratory-confirmed case        Missing  Missing
# ...              ...                        ...            ...      ...
# 27879428     Missing  Laboratory-confirmed case        Missing  Missing
# 27879429     Missing  Laboratory-confirmed case        Missing  Missing
# 27879430     Missing  Laboratory-confirmed case        Missing  Missing
# 27879431     Missing  Laboratory-confirmed case        Missing  Missing
# 27879432     Missing  Laboratory-confirmed case        Missing  Missing
#
#            icu_yn death_yn underlying_conditions_yn
# 0         Missing       No                      NaN
# 1         Missing  Unknown                      NaN
# 2         Missing      NaN                      Yes
# 3         Missing  Missing                      NaN
# 4         Missing       No                      NaN
# ...           ...      ...                      ...
# 27879428  Missing  Missing                      NaN
# 27879429  Missing  Missing                      NaN
# 27879430  Missing  Missing                      NaN
# 27879431  Missing  Missing                      NaN
# 27879432  Missing  Missing                      NaN
#
# [27879433 rows x 19 columns]

# %%
data = data.drop(columns=['process', 'exposure_yn', 'icu_yn', 'case_positive_specimen_interval', 'underlying_conditions_yn', 'res_state', 'res_county'])
data = data.dropna()
data
# Out:
#          case_month  state_fips_code  county_fips_code       age_group  \
# 12          2020-11             17.0           17063.0  18 to 49 years
# 30          2020-10             17.0           17049.0       65+ years
# 43          2020-11              8.0            8059.0    0 - 17 years
# 46          2021-03             17.0           17089.0  18 to 49 years
# 47          2021-02             34.0           34003.0  18 to 49 years
# ...             ...              ...               ...             ...
# 27569920    2020-12              6.0            6037.0  18 to 49 years
# 27569970    2020-12              6.0            6037.0  18 to 49 years
# 27570159    2020-12              6.0            6037.0  50 to 64 years
# 27570203    2020-12              6.0            6037.0  50 to 64 years
# 27570281    2020-12              6.0            6037.0  50 to 64 years
#
#               sex     race        ethnicity  case_onset_interval  \
# 12         Female  Missing          Missing                  0.0
# 30           Male  Missing          Missing                  0.0
# 43         Female  Missing  Hispanic/Latino                  0.0
# 46         Female  Missing  Hispanic/Latino                  0.0
# 47         Female    Asian  Hispanic/Latino                  0.0
# ...           ...      ...              ...                  ...
# 27569920  Unknown    White  Hispanic/Latino                  0.0
# 27569970  Unknown    White  Hispanic/Latino                  0.0
# 27570159  Unknown    White  Hispanic/Latino                  0.0
# 27570203  Unknown    White  Hispanic/Latino                  0.0
# 27570281  Unknown    White  Hispanic/Latino                  0.0
#
#                      current_status symptom_status  hosp_yn death_yn
# 12        Laboratory-confirmed case        Missing  Missing  Missing
# 30                    Probable Case        Missing  Missing  Missing
# 43        Laboratory-confirmed case    Symptomatic       No  Missing
# 46        Laboratory-confirmed case        Missing  Missing  Missing
# 47        Laboratory-confirmed case    Symptomatic       No       No
# ...                             ...            ...      ...      ...
# 27569920  Laboratory-confirmed case    Symptomatic  Unknown       No
# 27569970  Laboratory-confirmed case    Symptomatic  Unknown       No
# 27570159  Laboratory-confirmed case    Symptomatic      Yes       No
# 27570203  Laboratory-confirmed case    Symptomatic  Unknown       No
# 27570281  Laboratory-confirmed case    Symptomatic  Unknown       No
#
# [9055259 rows x 12 columns]

# %% [markdown]
# ## Binary Categories

# %%
# print(np.unique(data.current_status))
data.current_status = data.current_status.map({'Laboratory-confirmed case': 1, 'Probable Case': 0}).astype(int)

# %%
# print(np.unique(data.sex))
data['sex_female'] = data.sex.map({'Female': 1, 'Male': 0, 'Missing': -1, 'Other': -1, 'Unknown': -1}).astype(int)
data = data.drop(columns=['sex'])

# %%
# print(np.unique(data.hosp_yn))
data.hosp_yn = data.hosp_yn.map({'No': 0, 'Yes': 1, 'Missing': -1, 'Unknown': -1}).astype(int)

# %%
# print(np.unique(data.death_yn))
data.death_yn = data.death_yn.map({'No': 0, 'Yes': 1, 'Missing': -1, 'Unknown': -1}).astype(int)

# %%
data.symptom_status = data.symptom_status.map({'Symptomatic': 1, 'Missing': 0}).astype(int)

# %%
data
# Out:
#          case_month  state_fips_code  county_fips_code       age_group  \
# 12          2020-11             17.0           17063.0  18 to 49 years
# 30          2020-10             17.0           17049.0       65+ years
# 43          2020-11              8.0            8059.0    0 - 17 years
# 46          2021-03             17.0           17089.0  18 to 49 years
# 47          2021-02             34.0           34003.0  18 to 49 years
# ...             ...              ...               ...             ...
# 27569920    2020-12              6.0            6037.0  18 to 49 years
# 27569970    2020-12              6.0            6037.0  18 to 49 years
# 27570159    2020-12              6.0            6037.0  50 to 64 years
# 27570203    2020-12              6.0            6037.0  50 to 64 years
# 27570281    2020-12              6.0            6037.0  50 to 64 years
#
#              race        ethnicity  case_onset_interval  current_status  \
# 12        Missing          Missing                  0.0               1
# 30        Missing          Missing                  0.0               0
# 43        Missing  Hispanic/Latino                  0.0               1
# 46        Missing  Hispanic/Latino                  0.0               1
# 47          Asian  Hispanic/Latino                  0.0               1
# ...           ...              ...                  ...             ...
# 27569920    White  Hispanic/Latino                  0.0               1
# 27569970    White  Hispanic/Latino                  0.0               1
# 27570159    White  Hispanic/Latino                  0.0               1
# 27570203    White  Hispanic/Latino                  0.0               1
# 27570281    White  Hispanic/Latino                  0.0               1
#
#           symptom_status  hosp_yn  death_yn  sex_female
# 12                     0       -1        -1           1
# 30                     0       -1        -1           0
# 43                     1        0        -1           1
# 46                     0       -1        -1           1
# 47                     1        0         0           1
# ...                  ...      ...       ...         ...
# 27569920               1       -1         0          -1
# 27569970               1       -1         0          -1
# 27570159               1        1         0          -1
# 27570203               1       -1         0          -1
# 27570281               1       -1         0          -1
#
# [9055259 rows x 12 columns]

# %% [markdown]
# ## Age Groups

# %%
data.age_group = data.age_group.map({'0 - 17 years': 0, '18 to 49 years': 18, '50 to 64 years': 50, '65+ years': 65, 'Missing': 'missing'})

data = pd.concat([data, pd.get_dummies(data['age_group'], prefix='age')], axis=1)
data = data.drop(columns=['age_group'])
data.head()
# Out:
#    case_month  state_fips_code  county_fips_code     race        ethnicity  \
# 12    2020-11             17.0           17063.0  Missing          Missing
# 30    2020-10             17.0           17049.0  Missing          Missing
# 43    2020-11              8.0            8059.0  Missing  Hispanic/Latino
# 46    2021-03             17.0           17089.0  Missing  Hispanic/Latino
# 47    2021-02             34.0           34003.0    Asian  Hispanic/Latino
#
#     case_onset_interval  current_status  symptom_status  hosp_yn  death_yn  \
# 12                  0.0               1               0       -1        -1
# 30                  0.0               0               0       -1        -1
# 43                  0.0               1               1        0        -1
# 46                  0.0               1               0       -1        -1
# 47                  0.0               1               1        0         0
#
#     sex_female  age_0  age_18  age_50  age_65  age_missing
# 12           1      0       1       0       0            0
# 30           0      0       0       0       1            0
# 43           1      1       0       0       0            0
# 46           1      0       1       0       0            0
# 47           1      0       1       0       0            0

# %% [markdown]
# ## Races/Ethnicities

# %%
data['race_missing'] = np.logical_or(data.race.str.contains('Missing'), data.race.str.contains('Unknown'))
data['ethnicity_missing'] = np.logical_or(data.ethnicity.str.contains('Missing'), data.ethnicity.str.contains('Unknown'))
data.head()
# Out:
#    case_month  state_fips_code  county_fips_code     race        ethnicity  \
# 12    2020-11             17.0           17063.0  Missing          Missing
# 30    2020-10             17.0           17049.0  Missing          Missing
# 43    2020-11              8.0            8059.0  Missing  Hispanic/Latino
# 46    2021-03             17.0           17089.0  Missing  Hispanic/Latino
# 47    2021-02             34.0           34003.0    Asian  Hispanic/Latino
#
#     case_onset_interval  current_status  symptom_status  hosp_yn  death_yn  \
# 12                  0.0               1               0       -1        -1
# 30                  0.0               0               0       -1        -1
# 43                  0.0               1               1        0        -1
# 46                  0.0               1               0       -1        -1
# 47                  0.0               1               1        0         0
#
#     sex_female  age_0  age_18  age_50  age_65  age_missing  race_missing  \
# 12           1      0       1       0       0            0          True
# 30           0      0       0       0       1            0          True
# 43           1      1       0       0       0            0          True
# 46           1      0       1       0       0            0          True
# 47           1      0       1       0       0            0         False
#
#     ethnicity_missing
# 12               True
# 30               True
# 43              False
# 46              False
# 47              False

# %%
data['race_native'] = data.race.str.contains('American Indian/Alaska Native')
data['race_asian'] = data.race.str.contains('Asian')
data['race_black'] = data.race.str.contains('Black')
data['race_other'] = data.race.str.contains('Multiple/Other')
data['race_native_pacific'] = data.race.str.contains('Native Hawaiian/Other Pacific Islander')
data['race_white'] = data.race.str.contains('White')

data['ethnicity_hispanic'] = data.ethnicity.str.contains('Hispanic/Latino')

data = data.drop(columns=['race', 'ethnicity'])
data
# Out:
#          case_month  state_fips_code  county_fips_code  case_onset_interval  \
# 12          2020-11             17.0           17063.0                  0.0
# 30          2020-10             17.0           17049.0                  0.0
# 43          2020-11              8.0            8059.0                  0.0
# 46          2021-03             17.0           17089.0                  0.0
# 47          2021-02             34.0           34003.0                  0.0
# ...             ...              ...               ...                  ...
# 27569920    2020-12              6.0            6037.0                  0.0
# 27569970    2020-12              6.0            6037.0                  0.0
# 27570159    2020-12              6.0            6037.0                  0.0
# 27570203    2020-12              6.0            6037.0                  0.0
# 27570281    2020-12              6.0            6037.0                  0.0
#
#           current_status  symptom_status  hosp_yn  death_yn  sex_female  \
# 12                     1               0       -1        -1           1
# 30                     0               0       -1        -1           0
# 43                     1               1        0        -1           1
# 46                     1               0       -1        -1           1
# 47                     1               1        0         0           1
# ...                  ...             ...      ...       ...         ...
# 27569920               1               1       -1         0          -1
# 27569970               1               1       -1         0          -1
# 27570159               1               1        1         0          -1
# 27570203               1               1       -1         0          -1
# 27570281               1               1       -1         0          -1
#
#           age_0  ...  age_missing  race_missing  ethnicity_missing  \
# 12            0  ...            0          True               True
# 30            0  ...            0          True               True
# 43            1  ...            0          True              False
# 46            0  ...            0          True              False
# 47            0  ...            0         False              False
# ...         ...  ...          ...           ...                ...
# 27569920      0  ...            0         False              False
# 27569970      0  ...            0         False              False
# 27570159      0  ...            0         False              False
# 27570203      0  ...            0         False              False
# 27570281      0  ...            0         False              False
#
#           race_native  race_asian  race_black  race_other  \
# 12              False       False       False       False
# 30              False       False       False       False
# 43              False       False       False       False
# 46              False       False       False       False
# 47              False        True       False       False
# ...               ...         ...         ...         ...
# 27569920        False       False       False       False
# 27569970        False       False       False       False
# 27570159        False       False       False       False
# 27570203        False       False       False       False
# 27570281        False       False       False       False
#
#           race_native_pacific  race_white  ethnicity_hispanic
# 12                      False       False               False
# 30                      False       False               False
# 43                      False       False                True
# 46                      False       False                True
# 47                      False       False                True
# ...                       ...         ...                 ...
# 27569920                False        True                True
# 27569970                False        True                True
# 27570159                False        True                True
# 27570203                False        True                True
# 27570281                False        True                True
#
# [9055259 rows x 23 columns]

# %%
drop_mask = (
    (data.current_status == 0)
    # Features
    | (data.sex_female == -1) | (data.age_missing == 1) | (data.race_missing)
    # Dependent Variables
    | (data.hosp_yn == -1) | (data.death_yn == -1)
)
data = data.loc[np.logical_not(drop_mask)]

# %%
data.iloc[:, 4:] = data.iloc[:, 4:].astype(bool)
# Out:
# C:\Users\paulsaegert\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py:1754: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)

# %%
data = data.reset_index()
data = data.drop(columns=['index', 'age_missing', 'race_missing', 'ethnicity_missing', 'current_status'])

# %%
data.state_fips_code = data.state_fips_code.astype(int)
data.county_fips_code = data.county_fips_code.astype(int)
data.case_onset_interval = data.case_onset_interval.astype(int)

data
# Out:
#         case_month  state_fips_code  county_fips_code  case_onset_interval  \
# 0          2021-02               34             34003                    0
# 1          2020-06               37             37107                    0
# 2          2021-02               51             51700                    0
# 3          2020-05               37             37163                    0
# 4          2021-02               51             51540                    0
# ...            ...              ...               ...                  ...
# 3718686    2020-04                6              6037                    0
# 3718687    2020-04                6              6037                    0
# 3718688    2020-04                6              6037                    0
# 3718689    2020-04                6              6037                    0
# 3718690    2021-06                6              6037                    0
#
#          symptom_status  hosp_yn  death_yn  sex_female  age_0  age_18  age_50  \
# 0                  True    False     False        True  False    True   False
# 1                  True    False     False        True  False    True   False
# 2                  True    False     False        True  False    True   False
# 3                  True    False     False        True   True   False   False
# 4                  True    False     False        True  False    True   False
# ...                 ...      ...       ...         ...    ...     ...     ...
# 3718686            True     True      True       False  False   False   False
# 3718687            True     True      True       False  False   False   False
# 3718688            True     True      True       False  False   False   False
# 3718689            True     True      True       False  False   False   False
# 3718690            True     True     False       False  False   False   False
#
#          age_65  race_native  race_asian  race_black  race_other  \
# 0         False        False        True       False       False
# 1         False        False       False       False       False
# 2         False        False       False       False        True
# 3         False        False       False       False       False
# 4         False        False       False       False       False
# ...         ...          ...         ...         ...         ...
# 3718686    True        False       False       False       False
# 3718687    True        False       False       False       False
# 3718688    True        False       False       False       False
# 3718689    True        False       False       False       False
# 3718690    True        False       False       False       False
#
#          race_native_pacific  race_white  ethnicity_hispanic
# 0                      False       False                True
# 1                      False        True                True
# 2                      False       False                True
# 3                      False        True                True
# 4                      False        True                True
# ...                      ...         ...                 ...
# 3718686                False        True                True
# 3718687                False        True                True
# 3718688                False        True                True
# 3718689                False        True                True
# 3718690                False        True                True
#
# [3718691 rows x 19 columns]

# %%
data = data[list(data.columns.values)[5:] + list(data.columns.values[:5])]

# %%
data.to_csv('../data/data_geo.csv')
